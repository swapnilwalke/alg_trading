# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mpl
import pandas_ta as ta

data = yf.download("ITC.NS",period="5y",interval="1d")
df = pd.DataFrame(data)
#print(df.describe())

df = df[['Adj Close']]
print(df.info())

# plot with matplotlib
plt.figure(figsize=(16,8))
plt.title('ITC')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Adj Close Price INR', fontsize=18)
plt.plot(df['Adj Close'])
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1236 entries, 2018-04-10 to 2023-04-10
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  1236 non-null   float64
# dtypes: float64(1)
# memory usage: 19.3 KB
# None
